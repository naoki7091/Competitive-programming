# %%
n , tdash = input().split()

n,tdash

# %%
n = int(n)
tdash = list(tdash)

# %%
s = []
for i in range(n):
    tmp = list(input())
    s.append(tmp)

s

# %%
# sが入力した文字列
# tdashが受け取った文字列

# sが送った文字列と等しい可能性のあるものを出力


def is_epual(s_in , tdash):
    if s_in == tdash :
        return True
    else:
        return False
    
def insert_chr(s_in,tdash):
    # tdashがインサートされてしまっている状態
    if len(s_in) + 1 == len(tdash):
        # 文字列の順番が等しくないといけない処理を記述
        s_in_index = 0
        for i in range(len(tdash)):
            if s_in[s_in_index] == tdash[i]:
                s_in_index += 1
        
        if s_in_index == len(s_in):
            return True
        else:
            return False
    else:
        return False
    

def delete_chr(s_in,tdash):
    
    if len(s_in) - 1 == len(tdash):
        tdash_index = 0
        for i in range(len(s_in)):
            if s_in[i] == tdash[tdash_index]:
                tdash_index += 1
                if tdash_index == len(tdash):
                    return True
        if tdash_index == len(tdash):
            return True
        else:
            return False
    else:
        return False
    

def change_one_chr(s_in,tdash):
    if len(s_in) == len(tdash):
        count = 0
        for i in range(len(s_in)):
            if s_in[i] == tdash[i]:
                count += 1
        
        if count == len(s_in) - 1:
            return True
        else:
            return False
    else:
        return False



for s_in in s:
    if  is_epual(s_in,tdash) or insert_chr(s_in,tdash) or delete_chr(s_in,tdash) or change_one_chr(s_in,tdash):
        print("Yes")
    else:
        print("No")
# Out:
# True

# %%
n , tdash = input().split()

n = int(n)

tdash = list(tdash)

s = []
for i in range(n):
    tmp = list(input())
    s.append(tmp)




# sが入力した文字列
# tdashが受け取った文字列

# sが送った文字列と等しい可能性のあるものを出力


def is_epual(s_in , tdash):
    if s_in == tdash :
        return True
    else:
        return False
    
def insert_chr(s_in,tdash):
    # tdashがインサートされてしまっている状態
    if len(s_in) + 1 == len(tdash):
        # 文字列の順番が等しくないといけない処理を記述
        s_in_index = 0
        for i in range(len(tdash)):
            if s_in[s_in_index] == tdash[i]:
                s_in_index += 1
                if s_in_index == len(s_in):
                    return True
        
        if s_in_index == len(s_in):
            return True
        else:
            return False
    else:
        return False
    

def delete_chr(s_in,tdash):
    
    if len(s_in) - 1 == len(tdash):
        tdash_index = 0
        for i in range(len(s_in)):
            if s_in[i] == tdash[tdash_index]:
                tdash_index += 1
                if tdash_index == len(tdash):
                    return True
        if tdash_index == len(tdash):
            return True
        else:
            return False
    else:
        return False
    

def change_one_chr(s_in,tdash):
    if len(s_in) == len(tdash):
        count = 0
        for i in range(len(s_in)):
            if s_in[i] == tdash[i]:
                count += 1
        
        if count == len(s_in) - 1:
            return True
        else:
            return False
    else:
        return False


count = 0
index = 0
ans = []
for s_in in s:
    index += 1
    if  is_epual(s_in,tdash) or insert_chr(s_in,tdash) or delete_chr(s_in,tdash) or change_one_chr(s_in,tdash):
       count += 1
       ans.append(index)

print(count)
for result in ans:
    print(result)
